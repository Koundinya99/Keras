# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Loading the dataset
df=pd.read_csv(r'C:\Users\medik\OneDrive\Desktop\CSV Files\pima-indians-diabetes.csv')
df
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
#Splitting the data
X=df.iloc[:,0:8]
Y=df.iloc[:,8]

# %%
#Importing keras libaries
from keras.models import Sequential
from keras.layers import Dense

# %%
#Creating a model
model=Sequential()
#Adding input layer with 8 neurons and first hidden layer with 12 neurons and relu as activaion function
model.add(Dense(12,input_dim=8,activation='relu'))
#Adding second hidden layer with 8 neurons and relu as activaion function
model.add(Dense(8,activation='relu'))
#Adding Output layer with 1 neuron and sigmoid as activaion function
model.add(Dense(1,activation='sigmoid'))
#Compiling the model (Backpropagation)
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
#Training the model (via fit)
model.fit(X,pd.DataFrame(Y),epochs=150,batch_size=10,verbose=2)
# Out:
# Epoch 1/150
# 77/77 - 0s - loss: 7.5512 - accuracy: 0.6467
# Epoch 2/150
# 77/77 - 0s - loss: 1.4985 - accuracy: 0.5763
# Epoch 3/150
# 77/77 - 0s - loss: 0.9955 - accuracy: 0.5580
# Epoch 4/150
# 77/77 - 0s - loss: 0.8289 - accuracy: 0.6050
# Epoch 5/150
# 77/77 - 0s - loss: 0.7775 - accuracy: 0.6076
# Epoch 6/150
# 77/77 - 0s - loss: 0.7204 - accuracy: 0.6441
# Epoch 7/150
# 77/77 - 0s - loss: 0.7139 - accuracy: 0.6180
# Epoch 8/150
# 77/77 - 0s - loss: 0.6716 - accuracy: 0.6545
# Epoch 9/150
# 77/77 - 0s - loss: 0.6530 - accuracy: 0.6649
# Epoch 10/150
# 77/77 - 0s - loss: 0.6410 - accuracy: 0.6649
# Epoch 11/150
# 77/77 - 0s - loss: 0.6477 - accuracy: 0.6714
# Epoch 12/150
# 77/77 - 0s - loss: 0.6446 - accuracy: 0.6780
# Epoch 13/150
# 77/77 - 0s - loss: 0.6200 - accuracy: 0.6871
# Epoch 14/150
# 77/77 - 0s - loss: 0.6271 - accuracy: 0.6858
# Epoch 15/150
# 77/77 - 0s - loss: 0.6191 - accuracy: 0.6858
# Epoch 16/150
# 77/77 - 0s - loss: 0.6295 - accuracy: 0.6793
# Epoch 17/150
# ...

# %%
#Evaluating the model
score=model.evaluate(X,Y)
# Out:
# 24/24 [==============================] - 0s 861us/step - loss: 0.5021 - accuracy: 0.7510

# %%
#Predictions
predict=model.predict(X)
check=[round(X[0]) for X in predict]
df.rename(columns={'1':'Actual'})
df['Predicted']=pd.DataFrame(check)
df.rename(columns={'1':'Actual'},inplace=True)
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#       6  148   72  35    0  33.6  0.627  50  Actual  Predicted
# 0     1   85   66  29    0  26.6  0.351  31       0          0
# 1     8  183   64   0    0  23.3  0.672  32       1          1
# 2     1   89   66  23   94  28.1  0.167  21       0          0
# 3     0  137   40  35  168  43.1  2.288  33       1          0
# 4     5  116   74   0    0  25.6  0.201  30       0          0
# 5     3   78   50  32   88  31.0  0.248  26       1          0
# 6    10  115    0   0    0  35.3  0.134  29       0          0
# 7     2  197   70  45  543  30.5  0.158  53       1          0
# 8     8  125   96   0    0   0.0  0.232  54       1          0
# 9     4  110   92   0    0  37.6  0.191  30       0          0
# 10   10  168   74   0    0  38.0  0.537  34       1          1
# 11   10  139   80   0    0  27.1  1.441  57       0          0
# 12    1  189   60  23  846  30.1  0.398  59       1          1
# 13    5  166   72  19  175  25.8  0.587  51       1          0
# ...
